# %%
from  Class_exercise import subFieldsinAI
from  Class_exercise import oddEven
from  Class_exercise import eligible
from  Class_exercise import percentage
from  Class_exercise import area_triangle

aiSub=subFieldsinAI()
aiSub.subfields()
print('\n')

chkOddEve=oddEven()
chkOddEve.oddEven()
print('\n')

chkEligible=eligible()
chkEligible.eligible()
print('\n')

findPercent=percentage()
findPercent.percentage()

print('\n')
findArea = area_triangle()
findArea.area_triangle()
# Out:
# Sub fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# Enter a number :  45
# 45 is odd number
# Enter your gender : female
# Enter your age : 54
# Eligible
#
#
# Enter your marks in  English :
#  56
# Enter your marks in  Tamil :
#  78
# Enter your marks in  Mathematics :
#  79
# Enter your marks in  Science :
#  75
# Enter your marks in  Social Science :
#  98
# Percentage in tenth :  77.2
# Enter height of the triangle  1: 12
# Enter breadth of the triangle 1: 8
# Enter height 1 of the triangle 2 : 12
# Enter height 2 of the triangle 2 : 10
# Enter breadth of the triangle 2 : 5
# The area of first triangle is :  48.0
# The perimeter of second triangle is :  27
