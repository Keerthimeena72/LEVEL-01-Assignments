# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
input("Enter your institute name")
# Out:
# Enter your institute name HOPE AI
# 'HOPE AI'

# %%
input("Enter your name : ")
input("Enter your age : ")
input("Enter your school name : ")
input("Enter your degree : ")
# Out:
# Enter your name :  Meenakshi Ramesh
# Enter your age :  54
# Enter your school name :  Vivekananda Vidyalaya
# Enter your degree :  M.B.A. Insurance
# 'M.B.A. Insurance '

# %%
a = int(input("a"))
b = int(input("b"))
add = a + b 
print("add = ", add)
# Out:
# a 43
# b 34
# add =  77

# %%
a = int(input("a"))
b = int(input("b"))
sub = a - b 
print("sub = ", sub)
# Out:
# a 43
# b 34
# sub =  9

# %%
a = int(input("a"))
b = int(input("b"))
mul = a * b 
print("mul = ", mul)
# Out:
# a 63
# b 97
# mul =  6111

# %%
#Division
a = int(input("a"))
b = int(input("b"))
div = a / b 
print("Float div = ", div)
# Out:
# a 76
# b 31
# Float div =  2.4516129032258065

# %%
# Floor Division
a = int(input("a"))
b = int(input("b"))
div = a // b 
print("Floor div = ", div)
# Out:
# a 76
# b 31
# Floor div =  2

# %%
#Modulo
a = int(input("a"))
b = int(input("b"))
Modulo = a % b 
print("Modulo = ", Modulo)
# Out:
# a 76
# b 31
# Modulo =  14

# %%
#Power
a = int(input("a"))
b = int(input("b"))
Power = a ** b 
print("Power = ", Power)
# Out:
# a 4
# b 4
# Power =  256
