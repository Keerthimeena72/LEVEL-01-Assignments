# %%
#create a function and lsit out the items in the list 
def subfields() :
    subFieldsinAI=["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
    print("Sub fields in AI are :")
    for fields in subFieldsinAI:
        print(fields)

# %%
subfields()
# Out:
# Sub fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
#Create a function that checks whether the given number is odd or even
def oddEven():
    num=int(input("Enter a number : ")) 
    if (num%2 == 0) : 
       print(num, "is even number")
    else : 
       print(num, "is odd number")

# %%
oddEven()
# Out:
# Enter a number :  25
# 25 is odd number

# %%
#Create a function that tells eligibility of marriage for male and female according to their age limit 
#like 21 for male and 18 for female
def eligible():
    gender = input("Enter your gender :")
    age = int(input("Enter your age :"))
    if (gender == "male") :
       if (age >= 21) : 
           print("Eligible")
       else : 
           print("Not Eligible")
    elif (gender == "female") :
       if (age >= 18) : 
           print("Eligible")
       else : 
           print("Not Eligible")

# %%
eligible()
# Out:
# Enter your gender : male
# Enter your age : 17
# Not Eligible

# %%
def percentage():
    subjects = ["English","Tamil","Mathematics","Science","Social Science"]
    total = 0 
    for sub in subjects :
        print("Enter your marks in ",sub, ":")
        marks = int(input())
        total = total + marks
    print("Percentage in tenth : ", total/5)

# %%
percentage()
# Out:
# Enter your marks in  English :
#  87
# Enter your marks in  Tamil :
#  83
# Enter your marks in  Mathematics :
#  67
# Enter your marks in  Science :
#  34
# Enter your marks in  Social Science :
#  76
# Percentage in tenth :  69.4

# %%
#print area and perimeter of triangle using functions
def triangle() :
    h1 = int(input("Enter height of the triangle  1:"))
    b1 = int(input("Enter breadth of the triangle 1:"))
    area = (h1 * b1 )/2
    h3 = int(input("Enter height of the triangle 2 :"))
    h4 = int(input("Enter height of the triangle 2 :"))
    b2 = int(input("Enter breadth of the triangle 2 :"))
    perimeter = h3 + h4 + b2 
    print("The area of first triangle is : ",area)
    print("The perimeter of second triangle is : ", perimeter)

# %%
triangle()
# Out:
# Enter height of the triangle  1: 8
# Enter breadth of the triangle 1: 4
# Enter height of the triangle 2 : 4
# Enter height of the triangle 2 : 6
# Enter breadth of the triangle 2 : 8
# The area of first triangle is :  16.0
# The perimeter of second triangle is :  18
